# %% [markdown]
# ### Reference and descriptions
# - Main reference: [Tensors.net](https://www.tensors.net/)
# - Documents descriptions:
#   - Author: Sung-Min, Park
#   - Date: Nov. 6, 2024
#
# ---

# %% [markdown]
# # **Tutorial 4: Canonical Forms**

# %%
### Initialization ###
import numpy as np  # Essential package for tensor network approaches
import torch        # one can use the pytorch for tensor network.

# %% [markdown]
# ## **T4.1: Multi-stage tensor decompositions**

# %% [markdown]
# ## **T4.2: Center of orthogonality (link centered)**

# %% [markdown]
# ## **T4.3: Canonical forms**

# %% [markdown]
# ## **T2.4: Restricted rank tensor approximations**
